# %%
from __future__ import division
from __future__ import print_function

import time
import argparse
import numpy as np

import torch
import torch.optim as optim

from utils import load_data,normalize,toy_data,norm_embed,nmi_score

import matplotlib.pyplot as plt

# %%
import torch.nn as nn
import torch.nn.functional as F
from layers import GraphConvolution, InnerProduct
from utils import norm_embed
import torch

# %%
class GNN(nn.Module):
    
    def __init__(self, batch_size, nfeat, nhid, ndim, mu0, sigma0, fixed):
        super(GNN, self).__init__()

        self.gc1 = GraphConvolution(batch_size, nfeat, nhid, mu0, sigma0, scale=False)
        self.fixed = fixed
        if self.fixed:
            self.embeddings = GraphConvolution(batch_size, nhid, 2*ndim, mu0, sigma0, scale=True)
        else:
            self.embeddings = GraphConvolution(batch_size, nhid, 4 * ndim, mu0, sigma0, scale=True)
        self.reconstructions = InnerProduct(2*ndim)

    def forward(self, x, adj):
        x = F.relu(self.gc1(x, adj))
        x = self.embeddings(x, adj)
        x = norm_embed(x)
        if self.fixed:
            mu = F.relu(self.reconstructions(x))
            return mu
        else:
            lr1, lr2 = torch.chunk(x, chunks=2, dim=2)
            mu = F.relu(self.reconstructions(lr1))
            sigma = F.relu(self.reconstructions(lr2))
            return mu, sigma

# %%
np.set_printoptions(suppress=True)
torch.set_printoptions(sci_mode=False,precision=8)

# %%
# Training settings
parser = argparse.ArgumentParser()
parser.add_argument('--no-cuda', action='store_true', default=False,
                    help='Disables CUDA training.')
parser.add_argument('--fastmode', action='store_true', default=False,
                    help='Validate during training pass.')
parser.add_argument('--seed', type=int, default=426, help='Random seed.')
parser.add_argument('--epochs', type=int, default=10000,
                    help='Number of epochs to train.')
parser.add_argument('--lr', type=float, default=0.001,
                    help='Initial learning rate.')
parser.add_argument('--weight_decay', type=float, default=10e-8,
                    help='Weight decay (L2 loss on parameters).')
parser.add_argument('--hidden', type=int, default=16,
                    help='Number of hidden units.')
parser.add_argument('--ndim', type=int, default=2,
                    help='Embeddings dimension.')

args = parser.parse_args(args=[])
args.cuda = not args.no_cuda and torch.cuda.is_available()

# %%
if 1:
    # Taxi Dataset Graph
    adj = load_data()
    #adj = load_data(daily=True)
else:
    #Toy Example Graph
    adj = toy_data()

# %%
def svdApprox(adj,dim,relu=False):
    adj = torch.FloatTensor(adj[0])
    U, S, Vh = torch.linalg.svd(adj)
    mu = torch.matmul(torch.matmul(U[:, :dim], torch.diag(S[:dim])), Vh[:dim, :])
    
    embedx = torch.matmul(U[:, :dim],torch.diag(torch.pow(S[:dim], 0.5)))
    embedy = torch.transpose(torch.matmul(torch.diag(torch.pow(S[:dim], 0.5)),Vh[:dim, :]),0,1)
    
    criterion = torch.nn.GaussianNLLLoss()
    if relu:
        crt = torch.nn.ReLU()
        mu = crt(mu)
    mse = torch.nn.MSELoss()
    mseloss = mse(torch.flatten(mu), torch.flatten(adj))
    sig = torch.sqrt(mseloss)
    sigma = sig * torch.ones(adj.shape)
    loss = criterion(torch.flatten(adj), torch.flatten(mu), torch.flatten(torch.square(sigma)))
    
    return mu,loss.item(),embedx,embedy

# %%
def GraphNeuralNet(adj,dim,fixed=False):
    
    # Set the random seed
    np.random.seed(args.seed)
    torch.manual_seed(args.seed)
    if args.cuda:
        torch.cuda.manual_seed(args.seed)
        
    args.ndim = dim
    
    adj_norm = normalize(adj)

    adj = torch.FloatTensor(np.array(adj))
    
    # loss function
    criterion = torch.nn.GaussianNLLLoss()
    
    
    #features = torch.FloatTensor(torch.eye(adj.shape[1]))
    #features = features.reshape((1,adj.shape[1],adj.shape[1]))
    #features = features.repeat(adj.shape[0], 1, 1)
    
    #svd features
    svd_mu,svd_loss,svdembedx,svdembedy = svdApprox(adj=adj,dim=dim)
    features = torch.cat((svdembedx,svdembedy),dim=1)
    features = features.unsqueeze(dim=0)
    

    # Model and optimizer
    model = GNN(batch_size=adj.shape[0],
                nfeat=features.shape[2],
                nhid=args.hidden,
                ndim=args.ndim*args.ndim,
                mu0=adj.mean(),
                sigma0=adj.std(),
                fixed=fixed)

    activation = {}
    def get_activation(name):
        def hook(model, input, output):
            activation[name] = output.detach()
        return hook

    model.embeddings.register_forward_hook(get_activation('embeddings'))
    

    if args.cuda:
        model.cuda()
        features = features.cuda()
        adj = adj.cuda()
        adj_norm = adj_norm.cuda()


    # Train model
    t_total = time.time()
    
    # NULL Model
    mu0 = adj.mean()*torch.ones(adj.shape[1:])
    sigma0 = adj.std()*torch.ones(adj.shape[1:])
    with torch.no_grad():
        loss0 = criterion(torch.flatten(adj), torch.flatten(mu0), torch.flatten(torch.square(sigma0)))

    optimizer = optim.Adam(model.parameters(),
                           lr=args.lr, weight_decay=args.weight_decay)

    for epoch in range(args.epochs):

        t = time.time()
        model.train()
        optimizer.zero_grad()
        
        if fixed:
            mu = model(features, adj_norm)
            with torch.no_grad():
                mse = torch.nn.MSELoss()
                mseloss = mse(torch.flatten(mu),torch.flatten(adj))
                sig = torch.sqrt(mseloss)
            sigma = sig * torch.ones(adj.shape,requires_grad=True)
        else:
            mu,sigma = model(features, adj_norm)
        
        loss = criterion(torch.flatten(adj), torch.flatten(mu), torch.flatten(torch.square(sigma))) 
        loss.backward()
        optimizer.step()

        if epoch == 0:
            best_loss = loss
        else:
            if loss < best_loss:
                best_loss = loss

        if epoch % 1000 == 0:
            print('Epoch: {:04d}'.format(epoch + 1),
                  'loss: {:.8f}'.format(best_loss.item()),
                  'time: {:.4f}s'.format(time.time() - t))
            

    print("Optimization Finished!")
    print("Total time elapsed: {:.4f}s".format(time.time() - t_total))
    
    return mu,best_loss.item(),loss0

# %%
fix_loss = []
nonfix_loss = []
svd_loss = []
svdrelu_loss = []
nmi_fix = []
nmi_nonfix = []
nmi_svd = []
nmi_svdrelu = []
dims = [x for x in range(1,15)]
for dim in dims:
    mu,loss,loss0 = GraphNeuralNet(adj=adj,dim=dim,fixed=True)
    fix_loss.append(loss)
    nmi_fix.append(nmi_score(adj[0],mu.reshape(adj.shape[1:]).detach()))
    mu,loss,loss0 = GraphNeuralNet(adj=adj,dim=dim)
    nonfix_loss.append(loss)
    nmi_nonfix.append(nmi_score(adj[0],mu.reshape(adj.shape[1:]).detach()))
    mu,loss,embedx,embedy = svdApprox(adj=adj,dim=dim)
    svd_loss.append(loss)
    nmi_svd.append(nmi_score(adj[0],mu.reshape(adj.shape[1:]).detach()))
    mu,loss,embedx,embedy = svdApprox(adj=adj,dim=dim,relu=True)
    svdrelu_loss.append(loss)
    nmi_svdrelu.append(nmi_score(adj[0],mu.reshape(adj.shape[1:]).detach()))
# Out:
# torch.Size([1, 265, 2])
# Epoch: 0001 loss: 23.64076614 time: 0.0030s
# Epoch: 1001 loss: 11.05638885 time: 0.0020s
# Epoch: 2001 loss: 11.05638885 time: 0.0020s
# Epoch: 3001 loss: 11.05638885 time: 0.0020s
# Epoch: 4001 loss: 11.05638885 time: 0.0020s
# Epoch: 5001 loss: 11.05638885 time: 0.0040s
# Epoch: 6001 loss: 11.05638885 time: 0.0020s
# Epoch: 7001 loss: 11.05638885 time: 0.0020s
# Epoch: 8001 loss: 11.05638885 time: 0.0020s
# Epoch: 9001 loss: 11.05638885 time: 0.0000s
# Optimization Finished!
# Total time elapsed: 21.2378s
# torch.Size([1, 265, 2])
# Epoch: 0001 loss: 21.03638268 time: 0.0030s
# Epoch: 1001 loss: 9.06831837 time: 0.0040s
# Epoch: 2001 loss: 9.06829643 time: 0.0020s
# Epoch: 3001 loss: 9.06825924 time: 0.0026s
# Epoch: 4001 loss: 9.06820774 time: 0.0030s
# Epoch: 5001 loss: 9.06814671 time: 0.0030s
# Epoch: 6001 loss: 9.06808853 time: 0.0020s
# Epoch: 7001 loss: 9.06802559 time: 0.0020s
# Epoch: 8001 loss: 9.06796837 time: 0.0030s
# Epoch: 9001 loss: 9.06791401 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 21.1567s
# torch.Size([1, 265, 4])
# Epoch: 0001 loss: 24.46376801 time: 0.0028s
# Epoch: 1001 loss: 11.30166912 time: 0.0025s
# Epoch: 2001 loss: 11.30166912 time: 0.0030s
# Epoch: 3001 loss: 11.30166912 time: 0.0020s
# Epoch: 4001 loss: 11.30166912 time: 0.0030s
# Epoch: 5001 loss: 11.30166912 time: 0.0030s
# Epoch: 6001 loss: 11.30166912 time: 0.0029s
# Epoch: 7001 loss: 11.30166912 time: 0.0030s
# Epoch: 8001 loss: 11.30166912 time: 0.0020s
# Epoch: 9001 loss: 11.30166912 time: 0.0030s
# Optimization Finished!
# Total time elapsed: 24.0467s
# torch.Size([1, 265, 4])
# Epoch: 0001 loss: 21.52276230 time: 0.0020s
# Epoch: 1001 loss: 9.81249332 time: 0.0020s
# Epoch: 2001 loss: 9.81249332 time: 0.0030s
# Epoch: 3001 loss: 9.81249332 time: 0.0020s
# Epoch: 4001 loss: 9.49002361 time: 0.0020s
# Epoch: 5001 loss: 8.71874046 time: 0.0020s
# Epoch: 6001 loss: 8.69172955 time: 0.0020s
# Epoch: 7001 loss: 8.64472294 time: 0.0020s
# Epoch: 8001 loss: 8.64283562 time: 0.0020s
# Epoch: 9001 loss: 8.64283562 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 21.9467s
# torch.Size([1, 265, 6])
# Epoch: 0001 loss: 24.85147476 time: 0.0035s
# Epoch: 1001 loss: 11.26222420 time: 0.0000s
# Epoch: 2001 loss: 11.26222420 time: 0.0020s
# Epoch: 3001 loss: 11.26222420 time: 0.0013s
# Epoch: 4001 loss: 11.26222420 time: 0.0030s
# Epoch: 5001 loss: 11.26222420 time: 0.0030s
# Epoch: 6001 loss: 11.26222420 time: 0.0020s
# Epoch: 7001 loss: 11.26222420 time: 0.0020s
# Epoch: 8001 loss: 11.26222420 time: 0.0020s
# Epoch: 9001 loss: 11.26222420 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 21.9113s
# torch.Size([1, 265, 6])
# Epoch: 0001 loss: 21.34493446 time: 0.0030s
# Epoch: 1001 loss: 9.88618755 time: 0.0030s
# Epoch: 2001 loss: 9.88618755 time: 0.0030s
# Epoch: 3001 loss: 9.88618755 time: 0.0030s
# Epoch: 4001 loss: 9.88618755 time: 0.0020s
# Epoch: 5001 loss: 9.88618755 time: 0.0020s
# Epoch: 6001 loss: 9.88618755 time: 0.0020s
# Epoch: 7001 loss: 9.88618755 time: 0.0020s
# Epoch: 8001 loss: 9.88618755 time: 0.0030s
# Epoch: 9001 loss: 9.88618755 time: 0.0030s
# Optimization Finished!
# Total time elapsed: 22.5309s
# torch.Size([1, 265, 8])
# Epoch: 0001 loss: 24.99563789 time: 0.0020s
# Epoch: 1001 loss: 11.35143280 time: 0.0010s
# Epoch: 2001 loss: 11.35143280 time: 0.0020s
# Epoch: 3001 loss: 11.35143280 time: 0.0015s
# Epoch: 4001 loss: 11.35143280 time: 0.0020s
# Epoch: 5001 loss: 11.35143280 time: 0.0020s
# Epoch: 6001 loss: 11.35143280 time: 0.0020s
# Epoch: 7001 loss: 11.35143280 time: 0.0020s
# Epoch: 8001 loss: 11.35143280 time: 0.0020s
# Epoch: 9001 loss: 11.35143280 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 20.8006s
# torch.Size([1, 265, 8])
# Epoch: 0001 loss: 21.40092278 time: 0.0020s
# Epoch: 1001 loss: 15.24846172 time: 0.0030s
# Epoch: 2001 loss: 15.24846172 time: 0.0030s
# Epoch: 3001 loss: 15.24846172 time: 0.0020s
# Epoch: 4001 loss: 15.24846172 time: 0.0030s
# Epoch: 5001 loss: 15.24846172 time: 0.0030s
# Epoch: 6001 loss: 15.24846172 time: 0.0030s
# Epoch: 7001 loss: 15.24846172 time: 0.0030s
# Epoch: 8001 loss: 15.24846172 time: 0.0020s
# Epoch: 9001 loss: 15.24846172 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 23.0695s
# torch.Size([1, 265, 10])
# Epoch: 0001 loss: 25.41368103 time: 0.0031s
# Epoch: 1001 loss: 11.35048580 time: 0.0030s
# Epoch: 2001 loss: 11.35048580 time: 0.0030s
# Epoch: 3001 loss: 11.35048580 time: 0.0030s
# Epoch: 4001 loss: 11.35048580 time: 0.0030s
# Epoch: 5001 loss: 11.35048580 time: 0.0000s
# Epoch: 6001 loss: 11.35048580 time: 0.0020s
# Epoch: 7001 loss: 11.35048580 time: 0.0020s
# Epoch: 8001 loss: 11.35048580 time: 0.0020s
# Epoch: 9001 loss: 11.35048580 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 22.3977s
# torch.Size([1, 265, 10])
# Epoch: 0001 loss: 21.87225342 time: 0.0030s
# Epoch: 1001 loss: 9.49900532 time: 0.0030s
# Epoch: 2001 loss: 9.49900532 time: 0.0020s
# Epoch: 3001 loss: 9.49900532 time: 0.0030s
# Epoch: 4001 loss: 9.49900532 time: 0.0020s
# Epoch: 5001 loss: 9.49900532 time: 0.0020s
# Epoch: 6001 loss: 9.49900532 time: 0.0030s
# Epoch: 7001 loss: 9.49900532 time: 0.0030s
# Epoch: 8001 loss: 9.49900532 time: 0.0020s
# Epoch: 9001 loss: 9.49900532 time: 0.0030s
# Optimization Finished!
# Total time elapsed: 24.9179s
# torch.Size([1, 265, 12])
# Epoch: 0001 loss: 26.05967522 time: 0.0020s
# Epoch: 1001 loss: 11.35143280 time: 0.0020s
# Epoch: 2001 loss: 11.35143280 time: 0.0020s
# Epoch: 3001 loss: 11.35143280 time: 0.0030s
# Epoch: 4001 loss: 11.35143280 time: 0.0020s
# Epoch: 5001 loss: 11.35143280 time: 0.0020s
# Epoch: 6001 loss: 11.35143280 time: 0.0020s
# Epoch: 7001 loss: 11.35143280 time: 0.0020s
# Epoch: 8001 loss: 11.35143280 time: 0.0030s
# Epoch: 9001 loss: 11.35143280 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 22.9228s
# torch.Size([1, 265, 12])
# Epoch: 0001 loss: 22.74804688 time: 0.0030s
# Epoch: 1001 loss: 16.90021133 time: 0.0030s
# Epoch: 2001 loss: 16.90021133 time: 0.0020s
# Epoch: 3001 loss: 16.90021133 time: 0.0020s
# Epoch: 4001 loss: 16.90021133 time: 0.0030s
# Epoch: 5001 loss: 16.90021133 time: 0.0030s
# Epoch: 6001 loss: 16.90021133 time: 0.0030s
# Epoch: 7001 loss: 16.90021133 time: 0.0030s
# Epoch: 8001 loss: 16.90021133 time: 0.0030s
# Epoch: 9001 loss: 16.90021133 time: 0.0030s
# Optimization Finished!
# Total time elapsed: 27.0474s
# torch.Size([1, 265, 14])
# Epoch: 0001 loss: 26.03636932 time: 0.0020s
# Epoch: 1001 loss: 11.08966732 time: 0.0020s
# Epoch: 2001 loss: 11.08965778 time: 0.0020s
# Epoch: 3001 loss: 11.08965778 time: 0.0030s
# Epoch: 4001 loss: 11.08965778 time: 0.0020s
# Epoch: 5001 loss: 11.08965778 time: 0.0030s
# Epoch: 6001 loss: 11.08965778 time: 0.0030s
# Epoch: 7001 loss: 11.08965778 time: 0.0020s
# Epoch: 8001 loss: 11.08965778 time: 0.0020s
# Epoch: 9001 loss: 11.08965778 time: 0.0030s
# Optimization Finished!
# Total time elapsed: 24.0670s
# torch.Size([1, 265, 14])
# Epoch: 0001 loss: 23.02245331 time: 0.0024s
# Epoch: 1001 loss: 14.52672482 time: 0.0030s
# Epoch: 2001 loss: 13.09885883 time: 0.0030s
# Epoch: 3001 loss: 13.09885883 time: 0.0030s
# Epoch: 4001 loss: 13.09885883 time: 0.0030s
# Epoch: 5001 loss: 13.09885883 time: 0.0030s
# Epoch: 6001 loss: 13.09885883 time: 0.0040s
# Epoch: 7001 loss: 13.09885883 time: 0.0000s
# Epoch: 8001 loss: 13.09885883 time: 0.0040s
# Epoch: 9001 loss: 13.09885883 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 29.1449s
# torch.Size([1, 265, 16])
# Epoch: 0001 loss: 25.80112076 time: 0.0030s
# Epoch: 1001 loss: 11.11043453 time: 0.0020s
# Epoch: 2001 loss: 11.11043453 time: 0.0020s
# Epoch: 3001 loss: 11.11043453 time: 0.0030s
# Epoch: 4001 loss: 11.11043453 time: 0.0022s
# Epoch: 5001 loss: 11.11043453 time: 0.0050s
# Epoch: 6001 loss: 11.11043453 time: 0.0030s
# Epoch: 7001 loss: 11.11043453 time: 0.0030s
# Epoch: 8001 loss: 11.11043453 time: 0.0030s
# Epoch: 9001 loss: 11.11043453 time: 0.0030s
# Optimization Finished!
# Total time elapsed: 24.9084s
# torch.Size([1, 265, 16])
# Epoch: 0001 loss: 22.92704773 time: 0.0030s
# Epoch: 1001 loss: 15.75943756 time: 0.0030s
# Epoch: 2001 loss: 15.75943756 time: 0.0030s
# Epoch: 3001 loss: 15.75943756 time: 0.0030s
# Epoch: 4001 loss: 15.75943756 time: 0.0030s
# Epoch: 5001 loss: 15.75943756 time: 0.0030s
# Epoch: 6001 loss: 15.75943756 time: 0.0030s
# Epoch: 7001 loss: 15.75943756 time: 0.0030s
# Epoch: 8001 loss: 15.75943756 time: 0.0030s
# Epoch: 9001 loss: 15.75943756 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 29.4933s
# torch.Size([1, 265, 18])
# Epoch: 0001 loss: 26.26148415 time: 0.0030s
# Epoch: 1001 loss: 11.10661030 time: 0.0030s
# Epoch: 2001 loss: 11.10661030 time: 0.0030s
# Epoch: 3001 loss: 11.10661030 time: 0.0030s
# Epoch: 4001 loss: 11.10661030 time: 0.0030s
# Epoch: 5001 loss: 11.10661030 time: 0.0030s
# Epoch: 6001 loss: 11.10661030 time: 0.0020s
# Epoch: 7001 loss: 11.10661030 time: 0.0020s
# Epoch: 8001 loss: 11.10661030 time: 0.0030s
# Epoch: 9001 loss: 11.10661030 time: 0.0025s
# Optimization Finished!
# Total time elapsed: 26.7412s
# torch.Size([1, 265, 18])
# Epoch: 0001 loss: 23.19739723 time: 0.0032s
# Epoch: 1001 loss: 14.08794975 time: 0.0030s
# Epoch: 2001 loss: 14.08794975 time: 0.0030s
# Epoch: 3001 loss: 14.08794975 time: 0.0040s
# Epoch: 4001 loss: 14.08794975 time: 0.0040s
# Epoch: 5001 loss: 14.08794975 time: 0.0030s
# Epoch: 6001 loss: 14.08794975 time: 0.0030s
# Epoch: 7001 loss: 14.08794975 time: 0.0030s
# Epoch: 8001 loss: 14.08794975 time: 0.0034s
# Epoch: 9001 loss: 14.08794975 time: 0.0040s
# Optimization Finished!
# Total time elapsed: 34.0111s
# torch.Size([1, 265, 20])
# Epoch: 0001 loss: 26.79125404 time: 0.0030s
# Epoch: 1001 loss: 11.11448193 time: 0.0030s
# Epoch: 2001 loss: 11.11382771 time: 0.0020s
# Epoch: 3001 loss: 11.07281590 time: 0.0030s
# Epoch: 4001 loss: 11.07281590 time: 0.0020s
# Epoch: 5001 loss: 11.07281590 time: 0.0030s
# Epoch: 6001 loss: 11.07281590 time: 0.0030s
# Epoch: 7001 loss: 11.07281590 time: 0.0020s
# Epoch: 8001 loss: 11.07281590 time: 0.0030s
# Epoch: 9001 loss: 11.07281590 time: 0.0030s
# Optimization Finished!
# Total time elapsed: 28.5628s
# torch.Size([1, 265, 20])
# Epoch: 0001 loss: 23.96229172 time: 0.0040s
# Epoch: 1001 loss: 15.88892174 time: 0.0040s
# Epoch: 2001 loss: 15.88892174 time: 0.0040s
# Epoch: 3001 loss: 15.88892174 time: 0.0040s
# Epoch: 4001 loss: 15.88892174 time: 0.0050s
# Epoch: 5001 loss: 15.88892174 time: 0.0040s
# Epoch: 6001 loss: 15.88892174 time: 0.0050s
# Epoch: 7001 loss: 15.88892174 time: 0.0067s
# Epoch: 8001 loss: 13.32063198 time: 0.0040s
# Epoch: 9001 loss: 13.32063198 time: 0.0030s
# Optimization Finished!
# Total time elapsed: 42.1983s
# torch.Size([1, 265, 22])
# Epoch: 0001 loss: 26.79247093 time: 0.0030s
# Epoch: 1001 loss: 11.08857632 time: 0.0030s
# Epoch: 2001 loss: 11.08848858 time: 0.0040s
# Epoch: 3001 loss: 11.08845806 time: 0.0020s
# Epoch: 4001 loss: 11.08845806 time: 0.0030s
# Epoch: 5001 loss: 11.08845806 time: 0.0030s
# Epoch: 6001 loss: 11.08845806 time: 0.0030s
# Epoch: 7001 loss: 11.08845806 time: 0.0030s
# Epoch: 8001 loss: 11.08845806 time: 0.0030s
# Epoch: 9001 loss: 11.08845806 time: 0.0030s
# Optimization Finished!
# Total time elapsed: 30.4028s
# torch.Size([1, 265, 22])
# Epoch: 0001 loss: 23.74653625 time: 0.0041s
# Epoch: 1001 loss: 16.92477226 time: 0.0030s
# Epoch: 2001 loss: 16.92477226 time: 0.0040s
# Epoch: 3001 loss: 16.92477226 time: 0.0040s
# Epoch: 4001 loss: 16.92477226 time: 0.0040s
# Epoch: 5001 loss: 16.92477226 time: 0.0050s
# Epoch: 6001 loss: 16.92477226 time: 0.0040s
# Epoch: 7001 loss: 16.92477226 time: 0.0040s
# Epoch: 8001 loss: 16.92477226 time: 0.0040s
# Epoch: 9001 loss: 16.92477226 time: 0.0030s
# Optimization Finished!
# Total time elapsed: 39.3193s
# torch.Size([1, 265, 24])
# Epoch: 0001 loss: 26.97383499 time: 0.0040s
# Epoch: 1001 loss: 11.35143471 time: 0.0030s
# Epoch: 2001 loss: 11.35143471 time: 0.0030s
# Epoch: 3001 loss: 11.35143471 time: 0.0040s
# Epoch: 4001 loss: 11.35143471 time: 0.0020s
# Epoch: 5001 loss: 11.35143280 time: 0.0040s
# Epoch: 6001 loss: 11.35143280 time: 0.0030s
# Epoch: 7001 loss: 11.35143280 time: 0.0020s
# Epoch: 8001 loss: 11.35143280 time: 0.0030s
# Epoch: 9001 loss: 11.35143280 time: 0.0030s
# Optimization Finished!
# Total time elapsed: 30.5361s
# torch.Size([1, 265, 24])
# Epoch: 0001 loss: 24.21496582 time: 0.0050s
# Epoch: 1001 loss: 17.33328438 time: 0.0040s
# Epoch: 2001 loss: 17.33328438 time: 0.0030s
# Epoch: 3001 loss: 17.33328438 time: 0.0040s
# Epoch: 4001 loss: 17.33328438 time: 0.0040s
# Epoch: 5001 loss: 17.33328438 time: 0.0050s
# Epoch: 6001 loss: 17.33328438 time: 0.0040s
# Epoch: 7001 loss: 17.33328438 time: 0.0050s
# Epoch: 8001 loss: 17.33328438 time: 0.0040s
# Epoch: 9001 loss: 17.33328438 time: 0.0030s
# Optimization Finished!
# Total time elapsed: 38.9625s
# torch.Size([1, 265, 26])
# Epoch: 0001 loss: 26.56032753 time: 0.0030s
# Epoch: 1001 loss: 11.22075558 time: 0.0050s
# Epoch: 2001 loss: 11.22075558 time: 0.0030s
# Epoch: 3001 loss: 11.22075558 time: 0.0040s
# Epoch: 4001 loss: 11.22075558 time: 0.0040s
# Epoch: 5001 loss: 11.22075558 time: 0.0040s
# Epoch: 6001 loss: 11.22075558 time: 0.0040s
# Epoch: 7001 loss: 11.22075558 time: 0.0040s
# Epoch: 8001 loss: 11.22075558 time: 0.0040s
# Epoch: 9001 loss: 11.22075558 time: 0.0020s
# Optimization Finished!
# Total time elapsed: 36.2472s
# torch.Size([1, 265, 26])
# Epoch: 0001 loss: 23.80236053 time: 0.0050s
# Epoch: 1001 loss: 16.87327194 time: 0.0040s
# Epoch: 2001 loss: 16.87327194 time: 0.0039s
# Epoch: 3001 loss: 16.87327194 time: 0.0060s
# Epoch: 4001 loss: 16.87327194 time: 0.0050s
# Epoch: 5001 loss: 16.87327194 time: 0.0050s
# Epoch: 6001 loss: 16.87327194 time: 0.0050s
# Epoch: 7001 loss: 16.87327194 time: 0.0015s
# Epoch: 8001 loss: 16.87327194 time: 0.0040s
# Epoch: 9001 loss: 16.87327194 time: 0.0040s
# Optimization Finished!
# Total time elapsed: 46.4266s
# torch.Size([1, 265, 28])
# Epoch: 0001 loss: 26.81096840 time: 0.0040s
# Epoch: 1001 loss: 11.35143566 time: 0.0040s
# Epoch: 2001 loss: 11.35143471 time: 0.0030s
# Epoch: 3001 loss: 11.35143471 time: 0.0040s
# Epoch: 4001 loss: 11.35143280 time: 0.0030s
# Epoch: 5001 loss: 11.35143280 time: 0.0040s
# Epoch: 6001 loss: 11.35143280 time: 0.0030s
# Epoch: 7001 loss: 11.35143280 time: 0.0030s
# Epoch: 8001 loss: 11.35143280 time: 0.0030s
# Epoch: 9001 loss: 11.35143280 time: 0.0050s
# Optimization Finished!
# Total time elapsed: 35.2906s
# torch.Size([1, 265, 28])
# Epoch: 0001 loss: 23.84384918 time: 0.0039s
# Epoch: 1001 loss: 17.00207520 time: 0.0040s
# Epoch: 2001 loss: 17.00207520 time: 0.0060s
# Epoch: 3001 loss: 17.00207520 time: 0.0040s
# Epoch: 4001 loss: 17.00207520 time: 0.0050s
# Epoch: 5001 loss: 17.00207520 time: 0.0044s
# Epoch: 6001 loss: 17.00207520 time: 0.0040s
# Epoch: 7001 loss: 17.00207520 time: 0.0050s
# Epoch: 8001 loss: 17.00207520 time: 0.0051s
# Epoch: 9001 loss: 17.00207520 time: 0.0040s
# Optimization Finished!
# Total time elapsed: 45.9959s

# %%
plt.plot(dims,fix_loss,label="Fixed Sigma")
plt.plot(dims,nonfix_loss,label="Flexible Sigma")
plt.plot(dims,svd_loss,label="SVD")
plt.plot(dims,svdrelu_loss,label="SVD Relu")
plt.xlabel("dim")
plt.ylabel("NLL")
plt.legend()
print("NMI Score")
print("{}\t {}\t {}\t {}\t {}".format("Dim","Nonfix","Fix","SVDRel","SVD"))
for i in dims:
    print("{}\t {:.4f}\t {:.4f}\t {:.4f}\t {:.4f}".format(i,nmi_nonfix[i-1],nmi_fix[i-1],nmi_svdrelu[i-1],nmi_svd[i-1]))
print("\n NLL0 = {}".format(loss0))
# Out:
# NMI Score
# Dim	 Nonfix	 Fix	 SVDRel	 SVD
# 1	 0.3915	 0.0000	 0.2876	 0.2876
# 2	 0.0348	 0.0000	 0.1402	 0.1398
# 3	 0.4007	 0.0000	 0.5515	 0.5641
# 4	 0.0286	 0.0143	 0.5796	 0.5796
# 5	 0.3017	 0.0152	 0.4615	 0.4505
# 6	 0.2172	 0.0030	 0.4768	 0.4793
# 7	 0.2430	 0.0074	 0.4769	 0.4840
# 8	 0.0355	 0.0086	 0.6455	 0.6455
# 9	 0.0355	 0.0189	 0.6530	 0.8369
# 10	 0.0286	 0.2976	 0.8318	 0.7844
# 11	 0.2248	 0.0049	 0.5178	 0.5241
# 12	 0.0286	 0.0028	 0.7023	 0.7023
# 13	 0.0348	 0.0113	 0.7023	 0.8107
# 14	 0.0347	 0.0028	 0.7023	 0.7086
#
#  NLL0 = 11.34196949005127
