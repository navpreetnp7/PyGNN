# %%
from __future__ import division
from __future__ import print_function

import time
import argparse
import numpy as np

import torch
import torch.optim as optim

from utils import load_data,normalize,toy_data,norm_embed,nmi_score

import matplotlib.pyplot as plt 

from sklearn.utils import shuffle

# %%
import torch.nn as nn
import torch.nn.functional as F
from layers import GraphConvolution, InnerProduct
from utils import norm_embed
import torch

# %%
class GNN(nn.Module):
    
    def __init__(self, batch_size, nfeat, nhid, ndim, mu0, sigma0, fixed):
        super(GNN, self).__init__()

        self.gc1 = GraphConvolution(batch_size, nfeat, nhid, mu0, sigma0, scale=False)
        self.fixed = fixed
        if self.fixed:
            self.embeddings = GraphConvolution(batch_size, nhid, 2*ndim, mu0, sigma0, scale=True)
            self.reconstructions = InnerProduct(2*ndim)
        else:
            self.embeddings = GraphConvolution(batch_size, nhid, 4 * ndim, mu0, sigma0, scale=True)
            self.reconstructions = InnerProduct(4*ndim)
        

    def forward(self, x, adj):
        x = self.gc1(x, adj)
        #x = self.embeddings(x, adj)
        #x = norm_embed(x)
        if self.fixed:
            mu = F.relu(self.reconstructions(x))
            return mu
        else:
            lr1, lr2 = torch.chunk(x, chunks=2, dim=2)
            mu = F.relu(self.reconstructions(lr1))
            sigma = F.relu(self.reconstructions(lr2))
            return mu, sigma

# %%
np.set_printoptions(suppress=True)
torch.set_printoptions(sci_mode=False,precision=8)

# %%
# Training settings
parser = argparse.ArgumentParser()
parser.add_argument('--no-cuda', action='store_true', default=False,
                    help='Disables CUDA training.')
parser.add_argument('--fastmode', action='store_true', default=False,
                    help='Validate during training pass.')
parser.add_argument('--seed', type=int, default=426, help='Random seed.')
parser.add_argument('--epochs', type=int, default=20001,
                    help='Number of epochs to train.')
parser.add_argument('--lr', type=float, default=0.00001,
                    help='Initial learning rate.')
parser.add_argument('--weight_decay', type=float, default=10e-4,
                    help='Weight decay (L2 loss on parameters).')
parser.add_argument('--hidden', type=int, default=16,
                    help='Number of hidden units.')
parser.add_argument('--ndim', type=int, default=2,
                    help='Embeddings dimension.')

args = parser.parse_args(args=[])
args.cuda = not args.no_cuda and torch.cuda.is_available()

# %%
if 1:
    # Taxi Dataset Graph
    adj = load_data()
    #adj = load_data(daily=True)
else:
    #Toy Example Graph
    adj = toy_data()

# %%
def svdApprox(adj,dim,relu=False):
    adj = torch.FloatTensor(adj[0])
    U, S, Vh = torch.linalg.svd(adj)
    mu = torch.matmul(torch.matmul(U[:, :dim], torch.diag(S[:dim])), Vh[:dim, :])
    
    embedx = torch.matmul(U[:, :dim],torch.diag(torch.pow(S[:dim], 0.5)))
    embedy = torch.transpose(torch.matmul(torch.diag(torch.pow(S[:dim], 0.5)),Vh[:dim, :]),0,1)
    
    criterion = torch.nn.GaussianNLLLoss()
    if relu:
        crt = torch.nn.ReLU()
        mu = crt(mu)
    mse = torch.nn.MSELoss()
    mseloss = mse(torch.flatten(mu), torch.flatten(adj))
    sig = torch.sqrt(mseloss)
    sigma = sig * torch.ones(adj.shape)
    loss = criterion(torch.flatten(adj), torch.flatten(mu), torch.flatten(torch.square(sigma)))
    
    return mu,sigma,loss.item(),embedx,embedy

# %%
def GraphNeuralNet(adj,dim,fixed=False):
    
    # Set the random seed
    np.random.seed(args.seed)
    torch.manual_seed(args.seed)
    if args.cuda:
        torch.cuda.manual_seed(args.seed)
        
    args.ndim = dim
    
    adj_norm = normalize(adj)

    adj = torch.FloatTensor(np.array(adj))
    
    # loss function
    criterion = torch.nn.GaussianNLLLoss()
    
    
    #features = torch.FloatTensor(torch.eye(adj.shape[1]))
    #features = features.reshape((1,adj.shape[1],adj.shape[1]))
    #features = features.repeat(adj.shape[0], 1, 1)
    
    # NULL Model
    mu0 = adj.mean()*torch.ones(adj.shape[1:])
    sigma0 = adj.std()*torch.ones(adj.shape[1:])
    with torch.no_grad():
        loss0 = criterion(torch.flatten(adj), torch.flatten(mu0), torch.flatten(torch.square(sigma0)))
    
    #svd features
    svd_mu,svd_sig,svd_loss,svdembedx,svdembedy = svdApprox(adj=adj,dim=dim)
    features = torch.cat((svdembedx,svdembedy),dim=1)
    if not fixed:
        mse = torch.nn.MSELoss()
        mseloss = mse(torch.flatten(svd_mu),torch.flatten(adj))
        sig = torch.sqrt(mseloss)/dim
        svd_sig = torch.ones(features.shape)*torch.sqrt(sig)
        features = torch.cat((features,svd_sig),dim=1)
    features = features.unsqueeze(dim=0)
    #with torch.no_grad():
        #svd_loss = criterion(torch.flatten(adj), torch.flatten(svd_mu), torch.flatten(torch.square(svd_sig)))
        #print(svd_loss)
    
    

    # Model and optimizer
    """model = GNN(batch_size=adj.shape[0],
                nfeat=features.shape[2],
                nhid=args.hidden*args.ndim,
                ndim=args.ndim,
                mu0=adj.mean(),
                sigma0=adj.std(),
                fixed=fixed)
"""
    
        
        
    model = GNN(batch_size=adj.shape[0],
                nfeat=adj.shape[1],
                nhid=adj.shape[1],
                ndim=args.ndim,
                mu0=adj.mean(),
                sigma0=adj.std(),
                fixed=fixed)
    
    
    """activation = {}
    def get_activation(name):
        def hook(model, input, output):
            activation[name] = output.detach()
        return hook

    model.embeddings.register_forward_hook(get_activation('embeddings'))"""
    

    if args.cuda:
        model.cuda()
        features = features.cuda()
        adj = adj.cuda()
        adj_norm = adj_norm.cuda()


    # Train model
    t_total = time.time()
    
    # NULL Model
    mu0 = adj.mean()*torch.ones(adj.shape[1:])
    sigma0 = adj.std()*torch.ones(adj.shape[1:])
    with torch.no_grad():
        loss0 = criterion(torch.flatten(adj), torch.flatten(mu0), torch.flatten(torch.square(sigma0)))

    optimizer = optim.Adam(model.parameters(),
                           lr=args.lr, weight_decay=args.weight_decay)
    
    

    for epoch in range(args.epochs):

        t = time.time()
        model.train()
        optimizer.zero_grad()
        
        
        
        if fixed:
            mu = model(features, adj_norm)
            with torch.no_grad():
                mse = torch.nn.MSELoss()
                mseloss = mse(torch.flatten(mu),torch.flatten(adj))
                sig = torch.sqrt(mseloss)
            sigma = sig * torch.ones(adj.shape,requires_grad=True)
        else:
            mu,sigma = model(features, adj_norm)
        
        
        loss = criterion(torch.flatten(adj), torch.flatten(mu), torch.flatten(torch.square(sigma))) 
        loss.backward()
        optimizer.step()

        if epoch == 0:
            best_loss = loss
        else:
            if loss < best_loss:
                best_loss = loss

        if epoch % 5000 == 0:
            print('Epoch: {:04d}'.format(epoch + 1),
                  'loss: {:.8f}'.format(best_loss.item()))
        
        adj[0],features[0],adj_norm[0] = shuffle(adj[0],features[0],adj_norm[0]) # batch number
            

    print("Optimization Finished!")
    print("Total time elapsed: {:.4f}s".format(time.time() - t_total))
    
    
    return mu,best_loss.item(),loss0

# %%
fix_loss = []
nonfix_loss = []
svd_loss = []
svdrelu_loss = []
nmi_fix = []
nmi_nonfix = []
nmi_svd = []
nmi_svdrelu = []
dims = [x for x in range(1,15)]
for dim in dims:
    print("Fixed Sigma dim {}".format(dim))
    mu,loss,loss0 = GraphNeuralNet(adj=adj,dim=dim,fixed=True)
    fix_loss.append(loss)
    nmi_fix.append(nmi_score(adj[0],mu.reshape(adj.shape[1:]).detach()))
    print("Flexible Sigma dim {}".format(dim))
    mu,loss,loss0 = GraphNeuralNet(adj=adj,dim=dim)
    nonfix_loss.append(loss)
    nmi_nonfix.append(nmi_score(adj[0],mu.reshape(adj.shape[1:]).detach()))
    mu,sig,loss,embedx,embedy = svdApprox(adj=adj,dim=dim)
    svd_loss.append(loss)
    nmi_svd.append(nmi_score(adj[0],mu.reshape(adj.shape[1:]).detach()))
    mu,sig,loss,embedx,embedy = svdApprox(adj=adj,dim=dim,relu=True)
    svdrelu_loss.append(loss)
    nmi_svdrelu.append(nmi_score(adj[0],mu.reshape(adj.shape[1:]).detach()))
# Out:
# Fixed Sigma dim 1
# Epoch: 0001 loss: 10.95440388
# Epoch: 5001 loss: 10.95440388
# Epoch: 10001 loss: 10.95440388
# Epoch: 15001 loss: 10.95440388
# Epoch: 20001 loss: 10.95440388
# Optimization Finished!
# Total time elapsed: 92.0309s
# Flexible Sigma dim 1
# Epoch: 0001 loss: 10.95440388
# Epoch: 5001 loss: 10.95440388
# Epoch: 10001 loss: 10.91323471
# Epoch: 15001 loss: 10.83925629
# Epoch: 20001 loss: 10.75455189
# Optimization Finished!
# Total time elapsed: 86.9056s
# Fixed Sigma dim 2
# Epoch: 0001 loss: 10.72826576
# Epoch: 5001 loss: 10.72826576
# Epoch: 10001 loss: 10.72826576
# Epoch: 15001 loss: 10.72826576
# Epoch: 20001 loss: 10.72826576
# Optimization Finished!
# Total time elapsed: 79.6259s
# Flexible Sigma dim 2
# Epoch: 0001 loss: 10.72826481
# Epoch: 5001 loss: 10.72826481
# Epoch: 10001 loss: 10.72826481
# Epoch: 15001 loss: 10.72826481
# Epoch: 20001 loss: 10.72826481
# Optimization Finished!
# Total time elapsed: 85.2159s
# Fixed Sigma dim 3
# Epoch: 0001 loss: 10.41265392
# Epoch: 5001 loss: 10.41265392
# Epoch: 10001 loss: 10.41265392
# Epoch: 15001 loss: 10.41265392
# Epoch: 20001 loss: 10.41265392
# Optimization Finished!
# Total time elapsed: 79.9406s
# Flexible Sigma dim 3
# Epoch: 0001 loss: 10.41266251
# Epoch: 5001 loss: 10.41266251
# Epoch: 10001 loss: 10.41266251
# Epoch: 15001 loss: 10.41266251
# Epoch: 20001 loss: 10.41266251
# Optimization Finished!
# Total time elapsed: 79.3506s
# Fixed Sigma dim 4
# Epoch: 0001 loss: 10.20869350
# Epoch: 5001 loss: 10.20869350
# Epoch: 10001 loss: 10.20869350
# Epoch: 15001 loss: 10.20869350
# Epoch: 20001 loss: 10.20869350
# Optimization Finished!
# Total time elapsed: 80.4959s
# Flexible Sigma dim 4
# Epoch: 0001 loss: 10.20890999
# Epoch: 5001 loss: 10.20890999
# Epoch: 10001 loss: 10.20890999
# Epoch: 15001 loss: 10.20890999
# Epoch: 20001 loss: 10.20890999
# Optimization Finished!
# Total time elapsed: 86.1468s
# Fixed Sigma dim 5
# Epoch: 0001 loss: 10.08040810
# Epoch: 5001 loss: 10.08040810
# Epoch: 10001 loss: 10.08040810
# Epoch: 15001 loss: 10.08040810
# Epoch: 20001 loss: 10.08040810
# Optimization Finished!
# Total time elapsed: 87.4402s
# Flexible Sigma dim 5
# Epoch: 0001 loss: 10.08060169
# Epoch: 5001 loss: 10.08060169
# Epoch: 10001 loss: 10.08060169
# Epoch: 15001 loss: 10.08060169
# Epoch: 20001 loss: 10.08060169
# Optimization Finished!
# Total time elapsed: 88.0455s
# Fixed Sigma dim 6
# Epoch: 0001 loss: 9.98619080
# Epoch: 5001 loss: 9.98619080
# Epoch: 10001 loss: 9.98619080
# Epoch: 15001 loss: 9.98619080
# Epoch: 20001 loss: 9.98619080
# Optimization Finished!
# Total time elapsed: 92.2146s
# Flexible Sigma dim 6
# Epoch: 0001 loss: 9.98627472
# Epoch: 5001 loss: 9.98627472
# Epoch: 10001 loss: 9.98627472
# Epoch: 15001 loss: 9.98627472
# Epoch: 20001 loss: 9.98627472
# Optimization Finished!
# Total time elapsed: 82.9608s
# Fixed Sigma dim 7
# Epoch: 0001 loss: 9.89500523
# Epoch: 5001 loss: 9.89500523
# Epoch: 10001 loss: 9.89500523
# Epoch: 15001 loss: 9.89500523
# Epoch: 20001 loss: 9.89500523
# Optimization Finished!
# Total time elapsed: 87.9971s
# Flexible Sigma dim 7
# Epoch: 0001 loss: 9.89503479
# Epoch: 5001 loss: 9.89503479
# Epoch: 10001 loss: 9.89503479
# Epoch: 15001 loss: 9.89503479
# Epoch: 20001 loss: 9.89503479
# Optimization Finished!
# Total time elapsed: 80.0535s
# Fixed Sigma dim 8
# Epoch: 0001 loss: 9.81505585
# Epoch: 5001 loss: 9.81505585
# Epoch: 10001 loss: 9.81505585
# Epoch: 15001 loss: 9.81505585
# Epoch: 20001 loss: 9.81505585
# Optimization Finished!
# Total time elapsed: 88.5924s
# Flexible Sigma dim 8
# Epoch: 0001 loss: 9.81507683
# Epoch: 5001 loss: 9.81507683
# Epoch: 10001 loss: 9.81507683
# Epoch: 15001 loss: 9.81507683
# Epoch: 20001 loss: 9.81507683
# Optimization Finished!
# Total time elapsed: 79.6948s
# Fixed Sigma dim 9
# Epoch: 0001 loss: 9.73391914
# Epoch: 5001 loss: 9.73391914
# Epoch: 10001 loss: 9.73391914
# Epoch: 15001 loss: 9.73391914
# Epoch: 20001 loss: 9.73391914
# Optimization Finished!
# Total time elapsed: 88.6979s
# Flexible Sigma dim 9
# Epoch: 0001 loss: 9.73394871
# Epoch: 5001 loss: 9.73394871
# Epoch: 10001 loss: 9.73394871
# Epoch: 15001 loss: 9.73394871
# Epoch: 20001 loss: 9.73394871
# Optimization Finished!
# Total time elapsed: 73.8189s
# Fixed Sigma dim 10
# Epoch: 0001 loss: 9.65957642
# Epoch: 5001 loss: 9.65957642
# Epoch: 10001 loss: 9.65957642
# Epoch: 15001 loss: 9.65957642
# Epoch: 20001 loss: 9.65957642
# Optimization Finished!
# Total time elapsed: 62.3286s
# Flexible Sigma dim 10
# Epoch: 0001 loss: 9.65959930
# Epoch: 5001 loss: 9.65959930
# Epoch: 10001 loss: 9.65959930
# Epoch: 15001 loss: 9.65959930
# Epoch: 20001 loss: 9.65959930
# Optimization Finished!
# Total time elapsed: 64.9479s
# Fixed Sigma dim 11
# Epoch: 0001 loss: 9.57401943
# Epoch: 5001 loss: 9.57401943
# Epoch: 10001 loss: 9.57401943
# Epoch: 15001 loss: 9.57401943
# Epoch: 20001 loss: 9.57401943
# Optimization Finished!
# Total time elapsed: 62.4642s
# Flexible Sigma dim 11
# Epoch: 0001 loss: 9.57409000
# Epoch: 5001 loss: 9.57409000
# Epoch: 10001 loss: 9.57409000
# Epoch: 15001 loss: 9.57409000
# Epoch: 20001 loss: 9.57409000
# Optimization Finished!
# Total time elapsed: 59.4542s
# Fixed Sigma dim 12
# Epoch: 0001 loss: 9.52081871
# Epoch: 5001 loss: 9.52081871
# Epoch: 10001 loss: 9.52081871
# Epoch: 15001 loss: 9.52081871
# Epoch: 20001 loss: 9.52081871
# Optimization Finished!
# Total time elapsed: 63.7155s
# Flexible Sigma dim 12
# Epoch: 0001 loss: 9.52084255
# Epoch: 5001 loss: 9.52084255
# Epoch: 10001 loss: 9.52084255
# Epoch: 15001 loss: 9.52084255
# Epoch: 20001 loss: 9.52084255
# Optimization Finished!
# Total time elapsed: 60.9014s
# Fixed Sigma dim 13
# Epoch: 0001 loss: 9.46570110
# Epoch: 5001 loss: 9.46570110
# Epoch: 10001 loss: 9.46570110
# Epoch: 15001 loss: 9.46570110
# Epoch: 20001 loss: 9.46570110
# Optimization Finished!
# Total time elapsed: 96.2001s
# Flexible Sigma dim 13
# Epoch: 0001 loss: 9.46573067
# Epoch: 5001 loss: 9.46573067
# Epoch: 10001 loss: 9.46573067
# Epoch: 15001 loss: 9.46573067
# Epoch: 20001 loss: 9.46573067
# Optimization Finished!
# Total time elapsed: 93.3882s
# Fixed Sigma dim 14
# Epoch: 0001 loss: 9.40320015
# Epoch: 5001 loss: 9.40320015
# Epoch: 10001 loss: 9.40320015
# Epoch: 15001 loss: 9.40320015
# Epoch: 20001 loss: 9.40320015
# Optimization Finished!
# Total time elapsed: 96.2918s
# Flexible Sigma dim 14
# Epoch: 0001 loss: 9.40327168
# Epoch: 5001 loss: 9.40327168
# Epoch: 10001 loss: 9.40327168
# Epoch: 15001 loss: 9.40327168
# Epoch: 20001 loss: 9.40327168
# Optimization Finished!
# Total time elapsed: 85.8511s

# %%
plt.plot(dims,fix_loss,label="Fixed Sigma")
plt.plot(dims,nonfix_loss,label="Flexible Sigma")
plt.plot(dims,svd_loss,label="SVD")
plt.plot(dims,svdrelu_loss,label="SVD Relu")
plt.xlabel("dim")
plt.ylabel("NLL")
plt.legend()
print("NMI Score")
print("{}\t {}\t {}\t {}\t {}".format("Dim","Nonfix","Fix","SVDRel","SVD"))
for i in range(len(dims)):
    print("{}\t {:.4f}\t {:.4f}\t {:.4f}\t {:.4f}".format(dims[i],nmi_nonfix[i-1],nmi_fix[i-1],nmi_svdrelu[i-1],nmi_svd[i-1]))
print("\n NLL0 = {}".format(loss0))
# Out:
# NMI Score
# Dim	 Nonfix	 Fix	 SVDRel	 SVD
# 1	 0.0426	 0.1413	 0.7023	 0.8179
# 2	 0.1644	 0.1261	 0.2884	 0.2876
# 3	 0.1082	 0.1251	 0.1398	 0.1398
# 4	 0.0867	 0.1250	 0.5515	 0.5641
# 5	 0.0822	 0.1182	 0.5796	 0.5796
# 6	 0.0822	 0.1208	 0.4615	 0.4505
# 7	 0.0563	 0.1349	 0.4768	 0.4725
# 8	 0.0713	 0.1349	 0.4769	 0.4840
# 9	 0.0422	 0.1413	 0.8637	 0.8637
# 10	 0.0385	 0.1413	 0.6530	 0.8369
# 11	 0.0416	 0.1413	 0.8404	 0.8232
# 12	 0.0430	 0.1415	 0.5178	 0.5241
# 13	 0.0426	 0.1415	 0.7086	 0.7023
# 14	 0.0426	 0.1415	 0.7023	 0.7023
#
#  NLL0 = 11.34196949005127

# %%
plt.bar(dims,fix_loss,color ='lightblue',width = 0.4)
plt.title("Fixed Sigma")
plt.xlabel("Dims")
plt.ylabel("NLL")
# Out:
# Text(0, 0.5, 'NLL')

# %%
plt.bar(dims,nonfix_loss,color ='red',width = 0.4)
plt.title("Flexible Sigma")
plt.xlabel("Dims")
plt.ylabel("NLL")
# Out:
# Text(0, 0.5, 'NLL')
